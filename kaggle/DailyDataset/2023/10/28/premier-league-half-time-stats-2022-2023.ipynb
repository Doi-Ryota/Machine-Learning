# %% [markdown]
# ## About Dataset
# The data was acquired from https://optaplayerstats.statsperform.com/en_GB/
#
# Welcome to the Premier League Half-Time Statistics dataset, an invaluable resource for those passionate about sports analytics, modelling, and live betting strategies. In this dataset, you'll find half-time statistics for 380 Premier League games, offering a unique glimpse into the mid-game dynamics of one of the most competitive football leagues in the world.
#
# In the world of sports betting, in-play betting has gained immense popularity. However, there is often a lack of accessible and comprehensive data for live betting modelling. This dataset, despite its size, serves as a stepping stone for those interested in building predictive models for live betting scenarios using half-time statistics.
#
# ## More information about the data
#
# **Foul conceded**
# A Foul Conceded is defined as any infringement penalised as foul play by a referee that results in a free-kick or penalty event. Offsides are not given as a foul conceded. Incidents where a match official has played advantage and subsequently cautioned a player, do not contribute towards the total foul count for the player or team. In these scenarios a free-kick or penalty event must occur for a foul to be awarded.
#
# **Foul won**
# A Foul Won is defined when a player wins a free kick or penalty for their team after being fouled by an opposing player. There are no fouls won for a handball, dive, back pass, illegal restart, dissent, GK 6-second violation or obstruction where a free kick is conceded.
#
# **Crosses**
# A ball played from a wide position targeting a teammate(s) in a central area within proximity to the Goal. The delivery must have an element of lateral movement from a wider position to more central area in front of Goal.
#
# **Tackle**
# A tackle is defined when a player connects with the ball in a legal, ground level challenge and successfully takes the ball away from the opposition player. The tackled player must be in controlled possession of the ball to be tackled by an opposition player. Both Tackle Won and Lost are categorised as tackles, but the outcome of the tackle (won or lost) is different based on where the ball goes after the tackle.
#
# ### https://www.kaggle.com/datasets/ahmetbinatlioglu/premier-league-half-time-stats-2022-2023

# %% [markdown]
# |Feature|
# |----|
# |date|
# |time|
# |attendance|
# |home_team|
# |away_team|
# |match_home_goals|
# |match_away_goals|
# |ht_home_goals|
# |ht_home_assists|
# |ht_home_red|
# |ht_home_yellow|
# |ht_home_corners_won|
# |ht_home_shots|
# |ht_home_shots_on_target|
# |ht_home_blocked_shotsht_home_passes|
# |ht_home_crosses|
# |ht_home_tackles|
# |ht_home_offsides|
# |ht_home_fouls_conceded|
# |ht_home_fouls_won|
# |ht_away_goals|
# |ht_away_assists|
# |ht_away_red|
# |ht_away_yellow|
# |ht_away_corners_won|
# |ht_away_shots|
# |ht_away_shots_on_target|
# |ht_away_blocked_shots|
# |ht_away_passes|
# |ht_away_crosses|
# |ht_away_tackles|
# |ht_away_offsides|
# |ht_away_fouls_conceded|
# |ht_away_fouls_won|

# %%
# Libraries required for visualization and data processing

# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore")


# to display all columns
pd.set_option("display.max_columns",None)

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv("/kaggle/input/premier-league-half-time-stats-2022-2023/premierLeague2022.csv")
print(df.shape)
df.head(3)
# Out:
# (380, 35)
#           date   time attendance       home_team                   away_team  \
# 0  28 May 2023  16:30     17,120    Brentford FC          Manchester City FC
# 1  28 May 2023  16:30     42,212  Aston Villa FC   Brighton & Hove Albion FC
# 2  28 May 2023  16:30     60,095      Arsenal FC  Wolverhampton Wanderers FC
#
#    match_home_goals  match_away_goals  ht_home_goals  ht_home_assists  \
# 0                 1                 0              0                0
# 1                 2                 1              2                2
# 2                 5                 0              3                2
#
#    ht_home_red  ht_home_yellow  ht_home_corners_won  ht_home_shots  \
# 0            0               0                    1              5
# 1            0               3                    2              6
# 2            0               0                    1              8
#
#    ht_home_shots_on_target  ht_home_blocked_shots  ht_home_passes  \
# ...

# %% [markdown]
# # Data details

# %%
df.describe()
# Out:
#        match_home_goals  match_away_goals  ht_home_goals  ht_home_assists  \
# count        380.000000        380.000000     380.000000       380.000000
# mean           1.634211          1.218421       0.739474         0.507895
# std            1.419944          1.183518       0.900319         0.763578
# min            0.000000          0.000000       0.000000         0.000000
# 25%            1.000000          0.000000       0.000000         0.000000
# 50%            1.000000          1.000000       1.000000         0.000000
# 75%            2.000000          2.000000       1.000000         1.000000
# max            9.000000          6.000000       5.000000         4.000000
#
#        ht_home_red  ht_home_yellow  ht_home_corners_won  ht_home_shots  \
# count   380.000000      380.000000           380.000000     380.000000
# mean      0.021053        0.557895             2.763158       6.660526
# std       0.143749        0.729561             2.083155       3.541390
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     380 non-null    object
#  1   time                     380 non-null    object
#  2   attendance               380 non-null    object
#  3   home_team                380 non-null    object
#  4   away_team                380 non-null    object
#  5   match_home_goals         380 non-null    int64
#  6   match_away_goals         380 non-null    int64
#  7   ht_home_goals            380 non-null    int64
#  8   ht_home_assists          380 non-null    int64
#  9   ht_home_red              380 non-null    int64
#  10  ht_home_yellow           380 non-null    int64
#  11  ht_home_corners_won      380 non-null    int64
#  12  ht_home_shots            380 non-null    int64
#  13  ht_home_shots_on_target  380 non-null    int64
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
try:
    df['time'] = pd.to_datetime(df['time'], format='%H:%M').dt.time
except:
    pass
tmp_df = df['time'].value_counts().sort_index()
plt.figure(figsize=(15,6))
sns.barplot(x=tmp_df.index,y=tmp_df)
plt.show()

# %%
df['attendance'] = pd.to_numeric(df['attendance'].str.replace(',', '', regex=True))

# %%
plt.figure(figsize=(12,6))
sns.histplot(df["attendance"])
plt.show()

# %%
df["ht_match_home_goals"] = df["match_home_goals"]/2
df["ht_match_away_goals"] = df["match_away_goals"]/2

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
tmp_df = df['match_home_goals'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(122)
tmp_df = df['match_away_goals'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.show()

# %%
plt.figure(figsize=(12,6))
tmp_df = (df['match_home_goals']-df['match_away_goals']).value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)
plt.show()

# %%
(df['match_home_goals']-df['match_away_goals']).mean()
# Out:
# 0.41578947368421054

# %% [markdown]
# ## The home team is scoring more points.

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
tmp_df = df['ht_home_goals'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(122)
tmp_df = df['ht_away_goals'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(121)
tmp_df = (df['ht_home_goals']-df["ht_match_home_goals"]).value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(122)
tmp_df = (df['ht_away_goals']-df["ht_match_away_goals"]).value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.show()

# %%
print(f"home:{(df['ht_home_goals']-df['ht_match_home_goals']).mean()}")
print(f"away:{(df['ht_away_goals']-df['ht_match_away_goals']).mean()}")
# Out:
# home:-0.07763157894736843
# home:-0.02763157894736842

# %% [markdown]
# ## I scored more points in the second half than in the first half.
# ## However, since the difference roughly follows the standard deviation, it can also be considered an error.

# %%
print(f"home:{df['ht_home_red'].mean()}")
print(f"away:{df['ht_away_red'].mean()}")
print(f"diff:{(df['ht_home_red']-df['ht_away_red']).mean()}")

plt.figure(figsize=(18,6))
plt.subplot(131)
tmp_df = df['ht_home_red'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(132)
tmp_df = df['ht_away_red'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(133)
tmp_df = (df['ht_home_red']-df['ht_away_red']).value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.show()
# Out:
# home:0.021052631578947368
# away:0.002631578947368421
# diff:0.018421052631578946

# %%
print(f"home:{df['ht_home_yellow'].mean()}")
print(f"away:{df['ht_away_yellow'].mean()}")
print(f"diff:{(df['ht_home_yellow']-df['ht_away_yellow']).mean()}")

plt.figure(figsize=(18,6))
plt.subplot(131)
tmp_df = df['ht_home_yellow'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(132)
tmp_df = df['ht_away_yellow'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(133)
tmp_df = (df['ht_home_yellow']-df['ht_away_yellow']).value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.show()
# Out:
# home:0.5578947368421052
# away:0.6421052631578947
# diff:-0.08421052631578947

# %%
print(f"home:{df['ht_home_offsides'].mean()}")
print(f"away:{df['ht_away_offsides'].mean()}")
print(f"diff:{(df['ht_home_offsides']-df['ht_away_offsides']).mean()}")

plt.figure(figsize=(18,6))
plt.subplot(131)
tmp_df = df['ht_home_offsides'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(132)
tmp_df = df['ht_away_offsides'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(133)
tmp_df = (df['ht_home_offsides']-df['ht_away_offsides']).value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.show()
# Out:
# home:0.8315789473684211
# away:0.8473684210526315
# diff:-0.015789473684210527

# %%
print(f"home:{df['ht_home_fouls_conceded'].mean()}")
print(f"away:{df['ht_away_fouls_conceded'].mean()}")
print(f"diff:{(df['ht_home_fouls_conceded']-df['ht_away_fouls_conceded']).mean()}")

plt.figure(figsize=(18,6))
plt.subplot(131)
tmp_df = df['ht_home_fouls_conceded'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(132)
tmp_df = df['ht_away_fouls_conceded'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(133)
tmp_df = (df['ht_home_fouls_conceded']-df['ht_away_fouls_conceded']).value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.show()
# Out:
# home:5.023684210526316
# away:5.234210526315789
# diff:-0.21052631578947367

# %% [markdown]
# ## Yellow is more likely to be given to away, while red is more likely to be given to home.

# %%
print(f"home:{df['ht_home_corners_won'].mean()}")
print(f"away:{df['ht_away_corners_won'].mean()}")
print(f"diff:{(df['ht_home_corners_won']-df['ht_away_corners_won']).mean()}")

plt.figure(figsize=(18,6))
plt.subplot(131)
tmp_df = df['ht_home_corners_won'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(132)
tmp_df = df['ht_away_corners_won'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(133)
tmp_df = (df['ht_home_corners_won']-df['ht_away_corners_won']).value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.show()
# Out:
# home:2.763157894736842
# away:1.9605263157894737
# diff:0.8026315789473685

# %%
print(f"home:{df['ht_home_shots'].mean()}")
print(f"away:{df['ht_away_shots'].mean()}")
print(f"diff:{(df['ht_home_shots']-df['ht_away_shots']).mean()}")

plt.figure(figsize=(18,6))
plt.subplot(131)
tmp_df = df['ht_home_shots'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(132)
tmp_df = df['ht_away_shots'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(133)
tmp_df = (df['ht_home_shots']-df['ht_away_shots']).value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.show()
# Out:
# home:6.660526315789474
# away:5.121052631578947
# diff:1.5394736842105263

# %%
print(f"home:{df['ht_home_shots_on_target'].mean()}")
print(f"away:{df['ht_away_shots_on_target'].mean()}")
print(f"diff:{(df['ht_home_shots_on_target']-df['ht_away_shots_on_target']).mean()}")

plt.figure(figsize=(18,6))
plt.subplot(131)
tmp_df = df['ht_home_shots_on_target'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(132)
tmp_df = df['ht_away_shots_on_target'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(133)
tmp_df = (df['ht_home_shots_on_target']-df['ht_away_shots_on_target']).value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.show()
# Out:
# home:2.3210526315789473
# away:1.8236842105263158
# diff:0.49736842105263157

# %%
print(f"home:{df['ht_home_passes'].mean()}")
print(f"away:{df['ht_away_passes'].mean()}")
print(f"diff:{(df['ht_home_passes']-df['ht_away_passes']).mean()}")

plt.figure(figsize=(18,6))
plt.subplot(131)
sns.histplot(df['ht_home_passes'])

plt.subplot(132)
sns.histplot(df['ht_away_passes'])

plt.subplot(133)
sns.histplot(df['ht_home_passes']-df['ht_away_passes'])

plt.show()
# Out:
# home:237.03684210526316
# away:231.0421052631579
# diff:5.994736842105263

# %%
print(f"home:{df['ht_home_crosses'].mean()}")
print(f"away:{df['ht_away_crosses'].mean()}")
print(f"diff:{(df['ht_home_crosses']-df['ht_away_crosses']).mean()}")

plt.figure(figsize=(18,6))
plt.subplot(131)
tmp_df = df['ht_home_crosses'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(132)
tmp_df = df['ht_away_crosses'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(133)
sns.histplot(df['ht_home_crosses']-df['ht_away_crosses'])

plt.show()
# Out:
# home:9.378947368421052
# away:6.928947368421053
# diff:2.45

# %% [markdown]
# ## Home has the upper hand when it comes to attacks.

# %%
print(f"home:{df['ht_home_blocked_shots'].mean()}")
print(f"away:{df['ht_away_blocked_shots'].mean()}")
print(f"diff:{(df['ht_home_blocked_shots']-df['ht_away_blocked_shots']).mean()}")

plt.figure(figsize=(18,6))
plt.subplot(131)
tmp_df = df['ht_home_blocked_shots'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(132)
tmp_df = df['ht_away_blocked_shots'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(133)
tmp_df = (df['ht_home_blocked_shots']-df['ht_away_blocked_shots']).value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.show()
# Out:
# home:1.936842105263158
# away:1.4078947368421053
# diff:0.5289473684210526

# %%
print(f"home:{df['ht_home_tackles'].mean()}")
print(f"away:{df['ht_away_tackles'].mean()}")
print(f"diff:{(df['ht_home_tackles']-df['ht_away_tackles']).mean()}")

plt.figure(figsize=(18,6))
plt.subplot(131)
tmp_df = df['ht_home_tackles'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(132)
tmp_df = df['ht_away_tackles'].value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.subplot(133)
tmp_df = (df['ht_home_tackles']-df['ht_away_tackles']).value_counts().sort_index()
sns.barplot(x=tmp_df.index,y=tmp_df)

plt.show()
# Out:
# home:8.052631578947368
# away:8.313157894736841
# diff:-0.26052631578947366

# %% [markdown]
# ## Thank you for visiting my Notebook.
# ## I'm look forward to your high evaluation.
# ## If you have any suggestions for improvement, please feel free to comment
