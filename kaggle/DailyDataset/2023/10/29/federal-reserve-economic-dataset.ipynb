# %% [markdown]
# ## I'm look forward to your high evaluation.
# ## If you have any suggestions for improvement, please comment!
# ### This dataset is about bicycle rentals in Seoul with 6543 rows and 11 columns.

# %% [markdown]
# |Feature|Example|D-type|Null-Count|
# |----|----|----|-----|
# |id|PCU113310113310|object|0|
# |title|Producer Price Index by Industry: Logging|object|0|
# |observation_start|1981-12-01|object|0|
# |observation_end|2023-09-01|object|0|
# |frequency|Monthly|object|0|
# |units|Index Dec 1981=100|object|0|
# |seasonal_adjustment|Not Seasonally Adjusted|object|0|
# |last_updated|2023-10-11 08:05:34-05|object|0|
# |popularity|1|int64|0|
# |group_popularity|13|object|0|int64|0|
# |notes|In January 2014, the Producer Price Index (PPI)...|object|1369|

# %% [markdown]
# ### Please see the [appendix](#app) for detailed column explanations.

# %%
# Libraries required for visualization and data processing

# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore")


# to display all columns
pd.set_option("display.max_columns",None)

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv("/kaggle/input/federal-reserve-economic-dataset/fred_series.csv", encoding='latin1')
print(df.shape)
df.head(3)
# Out:
# (6543, 11)
#                   id                                              title  \
# 0    PCU113310113310          Producer Price Index by Industry: Logging
# 1   PCU113310113310M  Producer Price Index by Industry: Logging: Mis...
# 2  PCU113310113310MM  Producer Price Index by Industry: Logging: Mis...
#
#   observation_start observation_end frequency               units  \
# 0        1981-12-01      2023-09-01   Monthly  Index Dec 1981=100
# 1        1986-06-01      2022-07-01   Monthly  Index Jun 1986=100
# 2        1986-06-01      1998-08-01   Monthly  Index Jun 1986=100
#
#        seasonal_adjustment            last_updated  popularity  \
# 0  Not Seasonally Adjusted  2023-10-11 08:05:34-05           1
# 1  Not Seasonally Adjusted  2022-12-09 08:00:44-06           2
# 2  Not Seasonally Adjusted  2015-05-15 08:52:31-05           0
#
#    group_popularity notes
# 0                13   NaN
# 1                 2   NaN
# 2                 2   NaN

# %% [markdown]
# # Data details

# %%
df.describe()
# Out:
#         popularity  group_popularity
# count  6543.000000        6543.00000
# mean      2.426104           3.71588
# std       7.438015          10.31360
# min       0.000000           0.00000
# 25%       0.000000           1.00000
# 50%       1.000000           1.00000
# 75%       1.000000           1.00000
# max      85.000000          93.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6543 entries, 0 to 6542
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   6543 non-null   object
#  1   title                6543 non-null   object
#  2   observation_start    6543 non-null   object
#  3   observation_end      6543 non-null   object
#  4   frequency            6543 non-null   object
#  5   units                6543 non-null   object
#  6   seasonal_adjustment  6543 non-null   object
#  7   last_updated         6543 non-null   object
#  8   popularity           6543 non-null   int64
#  9   group_popularity     6543 non-null   int64
#  10  notes                5174 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 562.4+ KB

# %%
df.isnull().sum()
# Out:
# id                        0
# title                     0
# observation_start         0
# observation_end           0
# frequency                 0
# units                     0
# seasonal_adjustment       0
# last_updated              0
# popularity                0
# group_popularity          0
# notes                  1369
# dtype: int64

# %% [markdown]
# <a id="app"></a>
# # Appendix
#
# ## id
# Unique identifier for each data entry.
# ## title
# Title of the economic data, specifying the industry or category.
# ## observation_start
# Start date of the economic data observation period.
# ## observation_end
# End date of the economic data observation period.
# ## frequency
# Frequency of data updates (e.g., monthly, quarterly).
# ## units
# Measurement units used in the data (e.g., index points).
# ## seasonal_adjustment
# Indicates whether seasonal adjustments are applied to the data, important for understanding data fluctuations over time.
# ## last_updated
# Date and time of the last data update, ensuring the data's timeliness and relevance.
# ## popularity
# A measure of the data's popularity or usage, indicating its significance and relevance in research and analysis.
# ## group_popularity
# Popularity ranking within a specific group or category, helping identify the data's importance within a particular context.
# ## notes
# Additional notes or information about the data, offering valuable context and insights for data interpretation.
#
# ### https://www.kaggle.com/datasets/dhavalrupapara/federal-reserve-economic-dataset
