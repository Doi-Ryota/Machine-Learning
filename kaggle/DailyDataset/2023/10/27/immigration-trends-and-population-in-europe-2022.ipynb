# %% [markdown]
# ### According to studies:
#
# - **2.3 million immigrants** entered the EU from non-EU countries in 2021, an **increase of almost 18%** compared with 2020.
# - **1.4 million people** previously residing in one EU Member State migrated to another Member State, an **increase of almost 17%** compared with 2020.
# - **23.8 million people (5.3%) of the 446.7 million people** living in the EU on 1 January 2022 were non-EU citizens.
# - In 2021, EU Member States granted **citizenship to 827 300 persons** having their usual residence on the EU territory, an **increase of around 14%** compared with 2020.
#
# ### https://www.kaggle.com/datasets/umarzafar/immigration-trends-and-population-in-europe

# %% [markdown]
# |Feature|
# |----|
# |EU COUNTRIES|
# |TOTAL IMMIGRANTS(IN THOUSANDS)|
# |IMMIGRANTS WITH NATIONALITY(THOUSANDS)|
# |IMMIGRANTS WITH NATIONALITY(%age)|
# |NON-NATIONAL IMMIGRANTS (THOUSANDS)|
# |NON-NATIONAL IMMIGRANTS (%age)|
# |NON_NATIONAL IMMIGRANTS FROM OTHER EU MEMBER STATES(THOUSANDS)|
# |NON_NATIONAL IMMIGRANTS FROM OTHER EU MEMBER STATES(%age)|
# |NON_NATIONAL IMMIGRANTS FROM NON-EU STATES(THOUSANDS)|
# |NON_NATIONAL IMMIGRANTS FROM NON-EU STATES(%age)|
# |STATELESS IMMIGRANTS(THOUSANDS)|
# |STATELESS IMMIGRANTS(%age)|
# |NUMBER OF IMMIGRANTS(PER THOUSAND INHABITANTS)|
# |DISTRIBUTION OF IMMIGRANTS IN %AGE (NATIONALS)|
# |DISTRIBUTION OF IMMIGRANTS IN %AGE (NON-NATIONALS)|
# |DISTRIBUTION OF IMMIGRANTS IN %AGE(UNKNOWN)|
# |PERCENTAGE OF IMMIGRANTS BY SEX(MALE)|
# |PERCENTAGE OF IMMIGRANTS BY SEX(FEMALE)|
# |%AGE OF NON-NATIONAL IMMIGRANTS IN TOTAL POPULATION(CITIZENS OF EU MEMBER STATES)|
# |%AGE OF NON-NATIONAL IMMIGRANTS IN TOTAL POPULATION(CITIZENS OF NON-EU COUNTRIES)|
# |%AGE OF FOREIGN BORN IMMIGRANTS BY TOTAL POPULATION|
# |%AGE OF BORN IN ANOTHER EU-MEMBER STATES|
# |%AGE OF BORN IN NON-EU COUNTRY|

# %%
# Libraries required for visualization and data processing

# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore")


# to display all columns
pd.set_option("display.max_columns",None)

# %% [markdown]
# # Data Loading

# %%
df = pd.read_csv("/kaggle/input/immigration-trends-and-population-in-europe/EU Immigrants.csv")
print(df.shape)
df.head(3)
# Out:
# (65, 23)
#   EU COUNTRIES  TOTAL IMMIGRANTS(IN THOUSANDS)  \
# 0      Austria                           118.5
# 1      Belgium                           139.7
# 2     Bulgaria                            39.5
#
#    IMMIGRANTS WITH NATIONALITY(THOUSANDS)  IMMIGRANTS WITH NATIONALITY(%age)  \
# 0                                     9.6                                8.1
# 1                                    17.4                               12.4
# 2                                    22.1                               56.0
#
#    NON-NATIONAL IMMIGRANTS (THOUSANDS)  NON-NATIONAL IMMIGRANTS (%age)  \
# 0                                108.8                            91.8
# 1                                121.7                            87.1
# 2                                 17.3                            43.9
#
#    NON_NATIONAL IMMIGRANTS FROM OTHER EU MEMBER STATES(THOUSANDS)  \
# 0                                               64.4
# ...

# %% [markdown]
# # Data details

# %%
df.describe()
# Out:
#        TOTAL IMMIGRANTS(IN THOUSANDS)  IMMIGRANTS WITH NATIONALITY(THOUSANDS)  \
# count                       31.000000                               31.000000
# mean                       127.506452                               30.774194
# std                        182.481314                               39.971039
# min                          0.700000                                0.200000
# 25%                         24.650000                                5.100000
# 50%                         57.100000                               16.200000
# 75%                        142.300000                               35.500000
# max                        874.400000                              149.500000
#
#        IMMIGRANTS WITH NATIONALITY(%age)  NON-NATIONAL IMMIGRANTS (THOUSANDS)  \
# count                          31.000000                            31.000000
# mean                           29.496774                            96.519355
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 23 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0   EU COUNTRIES                                                                       31 non-null     object
#  1   TOTAL IMMIGRANTS(IN THOUSANDS)                                                     31 non-null     float64
#  2   IMMIGRANTS WITH NATIONALITY(THOUSANDS)                                             31 non-null     float64
#  3   IMMIGRANTS WITH NATIONALITY(%age)                                                  31 non-null     float64
#  4   NON-NATIONAL IMMIGRANTS (THOUSANDS)                                                31 non-null     float64
# ...

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("TOTAL IMMIGRANTS(IN THOUSANDS)",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["TOTAL IMMIGRANTS(IN THOUSANDS)"])
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("IMMIGRANTS WITH NATIONALITY(THOUSANDS)",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["IMMIGRANTS WITH NATIONALITY(THOUSANDS)"])
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("IMMIGRANTS WITH NATIONALITY(%age)",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["IMMIGRANTS WITH NATIONALITY(%age)"])
plt.show()

# %% [markdown]
# ## The problem is that accepting a large number of immigrants does not necessarily give them nationality.

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("NON_NATIONAL IMMIGRANTS FROM OTHER EU MEMBER STATES(THOUSANDS)",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["NON_NATIONAL IMMIGRANTS FROM OTHER EU MEMBER STATES(THOUSANDS)"])
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("NON_NATIONAL IMMIGRANTS FROM OTHER EU MEMBER STATES(%age)",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["NON_NATIONAL IMMIGRANTS FROM OTHER EU MEMBER STATES(%age)"])
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("NON_NATIONAL IMMIGRANTS FROM NON-EU STATES(THOUSANDS)",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["NON_NATIONAL IMMIGRANTS FROM NON-EU STATES(THOUSANDS)"])
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("NON_NATIONAL IMMIGRANTS FROM NON-EU STATES(%age)",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["NON_NATIONAL IMMIGRANTS FROM NON-EU STATES(%age)"])
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("STATELESS IMMIGRANTS(THOUSANDS)",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["STATELESS IMMIGRANTS(THOUSANDS)"])
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("STATELESS IMMIGRANTS(%age)",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["STATELESS IMMIGRANTS(%age)"])
plt.show()

# %% [markdown]
# ## What region did these people come from?

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("NUMBER OF IMMIGRANTS(PER THOUSAND INHABITANTS)",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["NUMBER OF IMMIGRANTS(PER THOUSAND INHABITANTS)"])
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("DISTRIBUTION OF IMMIGRANTS IN %AGE (NATIONALS)",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["DISTRIBUTION OF IMMIGRANTS IN %AGE (NATIONALS)"])
plt.show()

# %% [markdown]
# ## Is there a large percentage of countries that border the sea?

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("PERCENTAGE OF IMMIGRANTS BY SEX(MALE)",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["PERCENTAGE OF IMMIGRANTS BY SEX(MALE)"])
plt.show()

# %% [markdown]
# ## There are slightly more men

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("%AGE OF NON-NATIONAL IMMIGRANTS IN TOTAL POPULATION(CITIZENS OF EU MEMBER STATES)",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["%AGE OF NON-NATIONAL IMMIGRANTS IN TOTAL POPULATION(CITIZENS OF EU MEMBER STATES)"])
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("%AGE OF NON-NATIONAL IMMIGRANTS IN TOTAL POPULATION(CITIZENS OF NON-EU COUNTRIES)",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["%AGE OF NON-NATIONAL IMMIGRANTS IN TOTAL POPULATION(CITIZENS OF NON-EU COUNTRIES)"])
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("%AGE OF FOREIGN BORN IMMIGRANTS BY TOTAL POPULATION",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["%AGE OF FOREIGN BORN IMMIGRANTS BY TOTAL POPULATION"])
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("%AGE OF BORN IN ANOTHER EU-MEMBER STATES",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["%AGE OF BORN IN ANOTHER EU-MEMBER STATES"])
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
tmp_df = df.sort_values("%AGE OF BORN IN NON-EU COUNTRY",ascending=False)
sns.barplot(x=tmp_df["EU COUNTRIES"],y=tmp_df["%AGE OF BORN IN NON-EU COUNTRY"])
plt.show()

# %% [markdown]
# ## Thank you for visiting my Notebook.
# ## I'm look forward to your high evaluation.
# ## If you have any suggestions for improvement, please feel free to comment
